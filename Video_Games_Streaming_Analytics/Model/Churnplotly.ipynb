# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %%
cutoff_times = pd.read_csv('/content/drive/My Drive/Colab Notebooks/laMon.csv',parse_dates = ['cutoff_time'])
cutoff_times = cutoff_times.drop_duplicates(subset = ['user_id', 'cutoff_time'])
cutoff_times.head(100)
# Out:
#     user_id cutoff_time  label  days_to_churn churn_date
# 0      6410  2018-01-01    NaN            NaN        NaN
# 1      6410  2018-02-01    NaN            NaN        NaN
# 2      9285  2018-04-01    NaN            NaN        NaN
# 3      9285  2018-05-01    NaN            NaN        NaN
# 4     12346  2019-04-01    NaN            NaN        NaN
# ..      ...         ...    ...            ...        ...
# 95    12875  2019-03-01    NaN            NaN        NaN
# 96    12877  2019-09-01    NaN            NaN        NaN
# 97    12877  2019-10-01    NaN            NaN        NaN
# 98    12878  2018-12-01    NaN            NaN        NaN
# 99    12878  2019-01-01    NaN            NaN        NaN
#
# [100 rows x 5 columns]

# %%
cutoff_times_1 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/laBi.csv',parse_dates = ['cutoff_time'])
cutoff_times_1 = cutoff_times_1.drop_duplicates(subset = ['user_id', 'cutoff_time'])
cutoff_times_1.head(100)
# Out:
#     user_id cutoff_time  label  days_to_churn churn_date
# 0      6410  2018-01-01    0.0            NaN        NaN
# 1      6410  2018-01-15    NaN            NaN        NaN
# 2      6410  2018-02-01    NaN            NaN        NaN
# 3      9285  2018-04-01    0.0            NaN        NaN
# 4      9285  2018-04-15    NaN            NaN        NaN
# ..      ...         ...    ...            ...        ...
# 95    12845  2018-07-01    NaN            NaN        NaN
# 96    12847  2019-10-01    0.0            NaN        NaN
# 97    12847  2019-10-15    NaN            NaN        NaN
# 98    12847  2019-11-01    NaN            NaN        NaN
# 99    12849  2019-08-01    0.0            NaN        NaN
#
# [100 rows x 5 columns]

# %%
churnCustomer_31 = cutoff_times.loc[cutoff_times['label'] ==1]

# %%
churnCustomer_31.to_csv(r'/content/drive/My Drive/Colab Notebooks/ChurnMon.csv', index = False)

# %%
churnCustomer_31
# Out:
#           user_id cutoff_time  label  days_to_churn  churn_date
# 7757        41652  2018-05-01    1.0           38.0  2018-06-08
# 7776        71336  2018-09-01    1.0           43.0  2018-10-14
# 7785        78892  2018-06-01    1.0           48.0  2018-07-19
# 7806       261767  2018-05-01    1.0           49.0  2018-06-19
# 7817       261767  2019-04-01    1.0           44.0  2019-05-15
# ...           ...         ...    ...            ...         ...
# 204493  517310649  2018-02-01    1.0           47.0  2018-03-20
# 204515  517312822  2019-01-01    1.0           41.0  2019-02-11
# 204529  517317196  2019-01-01    1.0           42.0  2019-02-12
# 204553  517344292  2019-10-01    1.0           41.0  2019-11-11
# 204569  517358310  2019-05-01    1.0           31.0  2019-06-01
#
# [13939 rows x 5 columns]

# %%
churnCustomer_14 = cutoff_times_1.loc[cutoff_times_1['label'] ==1]

# %%
churnCustomer_14
# Out:
#           user_id cutoff_time  label  days_to_churn  churn_date
# 11636       41652  2018-05-01    1.0           21.0  2018-05-22
# 11673       71336  2018-09-01    1.0           26.0  2018-09-27
# 11691       78892  2018-06-15    1.0           17.0  2018-07-02
# 11725      261767  2018-05-15    1.0           18.0  2018-06-02
# 11746      261767  2019-04-01    1.0           27.0  2019-04-28
# ...           ...         ...    ...            ...         ...
# 365964  517310649  2018-02-15    1.0           16.0  2018-03-03
# 366006  517312822  2019-01-01    1.0           24.0  2019-01-25
# 366033  517317196  2019-01-01    1.0           25.0  2019-01-26
# 366071  517344292  2019-10-01    1.0           24.0  2019-10-25
# 366098  517358310  2019-05-01    1.0           14.0  2019-05-15
#
# [15141 rows x 5 columns]

# %%
churnCustomer_14.to_csv(r'/content/drive/My Drive/Colab Notebooks/ChurnBi.csv', index = False)

# %%
df= cutoff_times['label'].value_counts()

# %%
df
# Out:
# 0.0    34804
# 1.0    13939
# Name: label, dtype: int64

# %%
a_dictionary = dict(df)
keys = list(a_dictionary.keys())
values = list(a_dictionary.values())

# %%
import plotly.graph_objects as go
colors = ['lightslategray',]*2
colors[1] = 'crimson'
fig = go.Figure([go.Bar(x=keys, y=values,marker_color=colors,
                        text=values,
            textposition='auto')])
fig.update_layout(title_text='Monthly Churn Rate',xaxis_title="Churn Prediction",
    yaxis_title="Count",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="632dcb50-b44f-4f42-95c8-7bd2fde244e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("632dcb50-b44f-4f42-95c8-7bd2fde244e8")) {
#                     Plotly.newPlot(
#                         '632dcb50-b44f-4f42-95c8-7bd2fde244e8',
# ...

# %%
df_1= cutoff_times_1['label'].value_counts()

# %%
df_1
# Out:
# 0.0    97203
# 1.0    15114
# Name: label, dtype: int64

# %%
a_dictionary_1 = dict(df_1)
keys_1 = list(a_dictionary_1.keys())
values_1 = list(a_dictionary_1.values())
import plotly.graph_objects as go
colors = ['lightslategray',]*2
colors[1] = 'crimson'
fig = go.Figure([go.Bar(x=keys_1, y=values_1,marker_color=colors,
                        text=values_1,
            textposition='auto')])
fig.update_layout(title_text='BiMonthly Churn Rate',xaxis_title="Churn Prediction",
    yaxis_title="Count")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2dc09dc9-a319-41b0-bf98-74fa7c45f87c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2dc09dc9-a319-41b0-bf98-74fa7c45f87c")) {
#                     Plotly.newPlot(
#                         '2dc09dc9-a319-41b0-bf98-74fa7c45f87c',
# ...

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/ChurnMon.csv',parse_dates = ['churn_date'])

# %%
df.groupby(df['churn_date'].dt.strftime('%B'))['user_id'].count().sort_values()
# Out:
# churn_date
# February      893
# January       960
# December     1047
# November     1125
# May          1140
# September    1143
# March        1150
# August       1158
# October      1204
# June         1279
# July         1418
# April        1422
# Name: user_id, dtype: int64

# %%
totalchurn=df.groupby(df['churn_date'].dt.year)['user_id'].count().sort_values()

# %%
totalchurn.to_frame(name='Numbers lost').reset_index()
# Out:
#    churn_date  Numbers lost
# 0        2020           252
# 1        2018          6772
# 2        2019          6915

# %%
include = df[df['churn_date'].dt.year == 2018]

# %%
include
# Out:
#          user_id cutoff_time  label  days_to_churn churn_date
# 0          41652  2018-05-01    1.0           38.0 2018-06-08
# 1          71336  2018-09-01    1.0           43.0 2018-10-14
# 2          78892  2018-06-01    1.0           48.0 2018-07-19
# 3         261767  2018-05-01    1.0           49.0 2018-06-19
# 5         274625  2018-06-01    1.0           40.0 2018-07-11
# ...          ...         ...    ...            ...        ...
# 13925  517086974  2018-02-01    1.0           36.0 2018-03-09
# 13928  517166490  2018-07-01    1.0           36.0 2018-08-06
# 13929  517183195  2018-09-01    1.0           60.0 2018-10-31
# 13930  517204137  2018-05-01    1.0           31.0 2018-06-01
# 13934  517310649  2018-02-01    1.0           47.0 2018-03-20
#
# [6772 rows x 5 columns]

# %%
s= include.groupby(include['churn_date'].dt.strftime('%B'))['user_id'].count().sort_values()

# %%
l=s.to_frame(name='Name').reset_index()

# %%
include1 = df[df['churn_date'].dt.year == 2019]

# %%
include1
# Out:
#          user_id cutoff_time  label  days_to_churn churn_date
# 4         261767  2019-04-01    1.0           44.0 2019-05-15
# 6         278302  2019-01-01    1.0           54.0 2019-02-24
# 8         320878  2019-03-01    1.0           54.0 2019-04-24
# 11        918616  2019-03-01    1.0           31.0 2019-04-01
# 12        918616  2019-06-01    1.0           54.0 2019-07-25
# ...          ...         ...    ...            ...        ...
# 13933  517300114  2019-01-01    1.0           36.0 2019-02-06
# 13935  517312822  2019-01-01    1.0           41.0 2019-02-11
# 13936  517317196  2019-01-01    1.0           42.0 2019-02-12
# 13937  517344292  2019-10-01    1.0           41.0 2019-11-11
# 13938  517358310  2019-05-01    1.0           31.0 2019-06-01
#
# [6915 rows x 5 columns]

# %%
include2=df[df['churn_date'].dt.year == 2020]

# %%
include2
# Out:
#          user_id cutoff_time  label  days_to_churn churn_date
# 57       4915486  2019-12-01    1.0           32.0 2020-01-02
# 66       5576990  2019-12-01    1.0           48.0 2020-01-18
# 102      7832442  2019-12-01    1.0           54.0 2020-01-24
# 129      9460020  2019-12-01    1.0           33.0 2020-01-03
# 256     18597277  2020-01-01    1.0           58.0 2020-02-28
# ...          ...         ...    ...            ...        ...
# 13552  501422708  2019-12-01    1.0           37.0 2020-01-07
# 13562  501610826  2019-12-01    1.0           54.0 2020-01-24
# 13632  503405013  2020-01-01    1.0           32.0 2020-02-02
# 13677  505080806  2019-12-01    1.0           50.0 2020-01-20
# 13896  515081797  2019-12-01    1.0           57.0 2020-01-27
#
# [252 rows x 5 columns]

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
x = pd.DataFrame(include.groupby(include['churn_date'].dt.strftime('%B'))['user_id'].count()).reset_index()
x['churn_date'] = pd.Categorical(x['churn_date'], categories=months, ordered=True)
x1=x.sort_values('churn_date')

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
y = pd.DataFrame(include1.groupby(include1['churn_date'].dt.strftime('%B'))['user_id'].count()).reset_index()
y['churn_date'] = pd.Categorical(y['churn_date'], categories=months, ordered=True)
y1=y.sort_values('churn_date')

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
z = pd.DataFrame(include2.groupby(include2['churn_date'].dt.strftime('%B'))['user_id'].count()).reset_index()
z['churn_date'] = pd.Categorical(z['churn_date'], categories=months, ordered=True)
z1=z.sort_values('churn_date')

# %%
z1
# Out:
#   churn_date  user_id
# 1    January      176
# 0   February       76

# %%
dd = pd.read_csv('/content/drive/My Drive/Colab Notebooks/ChurnBi.csv',parse_dates = ['churn_date'])

# %%
dd.groupby(dd['churn_date'].dt.strftime('%B'))['user_id'].count().sort_values()
# Out:
# churn_date
# February      980
# January      1067
# December     1145
# November     1175
# August       1229
# April        1249
# October      1269
# July         1286
# September    1325
# May          1406
# June         1453
# March        1557
# Name: user_id, dtype: int64

# %%
totalchurn_1=dd.groupby(dd['churn_date'].dt.year)['user_id'].count().sort_values()

# %%
totalchurn_1
# Out:
# churn_date
# 2020     247
# 2019    7238
# 2018    7656
# Name: user_id, dtype: int64

# %%
exclude = dd[dd['churn_date'].dt.year == 2018]

# %%
exclude
# Out:
#          user_id cutoff_time  label  days_to_churn churn_date
# 0          41652  2018-05-01    1.0           21.0 2018-05-22
# 1          71336  2018-09-01    1.0           26.0 2018-09-27
# 2          78892  2018-06-15    1.0           17.0 2018-07-02
# 3         261767  2018-05-15    1.0           18.0 2018-06-02
# 5         274625  2018-06-01    1.0           23.0 2018-06-24
# ...          ...         ...    ...            ...        ...
# 15129  517166490  2018-07-01    1.0           19.0 2018-07-20
# 15130  517183195  2018-09-15    1.0           29.0 2018-10-14
# 15131  517204137  2018-05-01    1.0           14.0 2018-05-15
# 15132  517204362  2018-09-01    1.0           15.0 2018-09-16
# 15136  517310649  2018-02-15    1.0           16.0 2018-03-03
#
# [7656 rows x 5 columns]

# %%
exclude1 = dd[dd['churn_date'].dt.year == 2019]
exclude1
# Out:
#          user_id cutoff_time  label  days_to_churn churn_date
# 4         261767  2019-04-01    1.0           27.0 2019-04-28
# 6         278302  2019-01-15    1.0           23.0 2019-02-07
# 8         320878  2019-03-15    1.0           23.0 2019-04-07
# 9         320878  2019-06-01    1.0           25.0 2019-06-26
# 12        918616  2019-03-01    1.0           14.0 2019-03-15
# ...          ...         ...    ...            ...        ...
# 15135  517300114  2019-01-01    1.0           19.0 2019-01-20
# 15137  517312822  2019-01-01    1.0           24.0 2019-01-25
# 15138  517317196  2019-01-01    1.0           25.0 2019-01-26
# 15139  517344292  2019-10-01    1.0           24.0 2019-10-25
# 15140  517358310  2019-05-01    1.0           14.0 2019-05-15
#
# [7238 rows x 5 columns]

# %%
exclude2 = dd[dd['churn_date'].dt.year == 2020]
exclude2
# Out:
#          user_id cutoff_time  label  days_to_churn churn_date
# 31       2535916  2020-02-01    1.0           14.0 2020-02-15
# 75       5576990  2019-12-15    1.0           17.0 2020-01-01
# 81       5959099  2019-12-15    1.0           17.0 2020-01-01
# 112      7832442  2019-12-15    1.0           23.0 2020-01-07
# 277     18597277  2020-01-15    1.0           27.0 2020-02-11
# ...          ...         ...    ...            ...        ...
# 14732  501610826  2019-12-15    1.0           23.0 2020-01-07
# 14805  503405013  2020-01-01    1.0           15.0 2020-01-16
# 14856  505080806  2019-12-15    1.0           19.0 2020-01-03
# 14913  506892991  2019-12-15    1.0           30.0 2020-01-14
# 15095  515081797  2019-12-15    1.0           26.0 2020-01-10
#
# [247 rows x 5 columns]

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
u = pd.DataFrame(exclude.groupby(exclude['churn_date'].dt.strftime('%B'))['user_id'].count()).reset_index()
u['churn_date'] = pd.Categorical(u['churn_date'], categories=months, ordered=True)
u1=u.sort_values('churn_date')

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
v = pd.DataFrame(exclude1.groupby(exclude1['churn_date'].dt.strftime('%B'))['user_id'].count()).reset_index()
v['churn_date'] = pd.Categorical(v['churn_date'], categories=months, ordered=True)
v1=v.sort_values('churn_date')

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
w = pd.DataFrame(exclude2.groupby(exclude2['churn_date'].dt.strftime('%B'))['user_id'].count()).reset_index()
w['churn_date'] = pd.Categorical(w['churn_date'], categories=months, ordered=True)
w1=w.sort_values('churn_date')

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=u1['churn_date'], y=u1['user_id'],
                    mode='lines+markers',
                    name='Bimonthly'))
fig.add_trace(go.Scatter(x=x1['churn_date'], y=x1['user_id'],
                    mode='lines+markers',
                    name='Monthly'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="86dd1fcb-4901-4d67-94ed-610c9e3293ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("86dd1fcb-4901-4d67-94ed-610c9e3293ce")) {
#                     Plotly.newPlot(
#                         '86dd1fcb-4901-4d67-94ed-610c9e3293ce',
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=v1['churn_date'], y=v1['user_id'],
                    mode='lines+markers',
                    name='bimonthly'))
fig.add_trace(go.Scatter(x=y1['churn_date'], y=y1['user_id'],
                    mode='lines+markers',
                    name='monthly'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ea2de895-a4a7-4d7d-9092-1d1b5c8f1b23" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ea2de895-a4a7-4d7d-9092-1d1b5c8f1b23")) {
#                     Plotly.newPlot(
#                         'ea2de895-a4a7-4d7d-9092-1d1b5c8f1b23',
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=w1['churn_date'], y=w1['user_id'],
                    mode='lines+markers',
                    name='bimonthly'))
fig.add_trace(go.Scatter(x=z1['churn_date'], y=z1['user_id'],
                    mode='lines+markers',
                    name='monthly'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1e0c6f6a-2e0c-4c17-a007-831ec4e2e174" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1e0c6f6a-2e0c-4c17-a007-831ec4e2e174")) {
#                     Plotly.newPlot(
#                         '1e0c6f6a-2e0c-4c17-a007-831ec4e2e174',
# ...
