# %%
#### import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import random
import numpy as np
import time
import os
import sys
import requests
from bs4 import BeautifulSoup
import pickle
from fake_useragent import UserAgent
import pandas as pd

url = 'https://www.twitch.tv/robots.txt'
response  = requests.get(url)
print(response.text)
# Out:
# User-Agent: *
# Allow: /
# Allow: /directory
# Allow: /directory/all
# Allow: /directory/*
# Allow: /videos/week
# Allow: /.well-known/assetlinks.json
# Disallow: /admin/*
# Disallow: /email-unsubscribe/
# Disallow: /login$
# Disallow: /message/*
# Disallow: /signup$
# Disallow: /user/*
#
# Sitemap: https://www.twitch.tv/sitemap_index.xml.gz
# Sitemap: https://www.twitch.tv/sitemap_naver_index.xml.gz

# %%
import sys
import requests
from bs4 import BeautifulSoup

url = 'https://www.twitch.tv/directory'

user_agent = {'User-agent': 'Safari/13.1'}
response  = requests.get(url, headers = user_agent)

# %%
ua = UserAgent()
user_agent = {'User-agent': ua.random}
print(user_agent)

response  = requests.get(url, headers = user_agent)
print(response.text)
# Out:
# {'User-agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/29.0.1547.2 Safari/537.36'}
# ...

# %% [markdown]
# ## Now to Selenium!
#
# ## What happens if I try to parse my gmail with `requests` and `BeautifulSoup`?

# %% [markdown]
# # Scraping Box Office Mojo with Selenium

# %%
chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver 

driver = webdriver.Chrome(chromedriver)

matrix_url = "https://www.twitch.tv/directory"
driver.get(matrix_url) #opens the matrix in the dummy google chrome

# %%
# 'contains' will find a match on the text, in this case return b tag
game_list = []
num = 2
while num < 1000:
    gross_selector = f'//*[@id="root"]/div/div[2]/div/main/div[1]/div[3]/div/div/div/div[4]/div/div[1]/div[{num}]/div/div/div/div/div[1]/div/div/div/div/span/a/h3'
    print(driver.find_element_by_xpath(gross_selector).text)
    game_list.append(driver.find_element_by_xpath(gross_selector).text)     
    time.sleep(.5+2*random.random())
    num+=1
# Out:
# VALORANT
# Fortnite
# Just Chatting
# Music & Performing Arts
# Call of Duty: Modern Warfare
# Final Fantasy VII Remake
# League of Legends
# Animal Crossing: New Horizons
# Minecraft
# Apex Legends
# Overwatch
# Tom Clancy's Rainbow Six: Siege
# Counter-Strike: Global Offensive
# World of Warcraft
# Escape From Tarkov
# Art
# Grand Theft Auto V
# Resident Evil 3
# ROBLOX
# Dead by Daylight
# Rocket League
# NBA 2K20
# Talk Shows & Podcasts
# Madden NFL 20
# Mount & Blade II: Bannerlord
# MLB The Show 20
# Super Smash Bros. Ultimate
# VRChat
# The Sims 4
# Teamfight Tactics
# Risk of Rain 2
# Marbles On Stream
# Sports & Fitness
# Hearthstone
# Destiny 2
# Old School RuneScape
# Doom Eternal
# The Jackbox Party Pack 3
# The Jackbox Party Pack 6
# Science & Technology
# Poker
# Dota 2
# Dungeons & Dragons
# PLAYERUNKNOWN'S BATTLEGROUNDS
# Persona 5: The Royal
# Pokémon Sword/Shield
# Last Oasis
# Super Mario Maker 2
# Magic: The Gathering
# Dark Souls
# ASMR
# Rust
# Games + Demos
# ...

# %%
from selenium.common.exceptions import *
# 'contains' will find a match on the text, in this case return b tag
game_list_cats = []

#this loop ends at retro games because retro games has no tag
num = 2
while num < 1000:
    try:
        #                   //*[@id="root"]/div/div[2]/div/main/div[1]/div[3]/div/div/div/div[4]/div/div[1]/div[2]/div/div/div/div/div[2]/div
        gross_selector = f'//*[@id="root"]/div/div[2]/div/main/div[1]/div[3]/div/div/div/div[4]/div/div[1]/div[{num}]/div/div/div/div/div[2]/div'
        print(driver.find_element_by_xpath(gross_selector).text.split('\n'))
        game_list_cats.append(driver.find_element_by_xpath(gross_selector).text.split('\n'))
        time.sleep(.5+2*random.random())
        num+=1
    except NoSuchElementException:
        print(['NONE'])
        game_list_cats.append(['NONE'])
        time.sleep(.5+2*random.random())        
        num+=1
# Out:
# ['Shooter', 'FPS']
# ['Shooter']
# ['IRL']
# ['IRL', 'Creative']
# ['FPS', 'Shooter']
# ['Action', 'RPG']
# ['MOBA']
# ['Simulation']
# ['Adventure Game', 'Action']
# ['FPS', 'Shooter']
# ['FPS', 'Shooter', 'MOBA']
# ['FPS', 'Shooter']
# ['FPS', 'Shooter']
# ['MMORPG', 'RPG']
# ['Simulation', 'FPS']
# ['Creative']
# ['Driving/Racing Game']
# ['Action', 'Adventure Game']
# ['MMORPG', 'RPG']
# ['Action', 'Horror']
# ['Driving/Racing Game']
# ['Sports Game', 'Simulation']
# ['IRL']
# ['Sports Game']
# ['Action', 'Adventure Game']
# ['Sports Game']
# ['Fighting', 'Platformer']
# ['Simulation', 'RPG']
# ['Simulation']
# ['Strategy', 'Autobattler']
# ['Action', 'Indie Game']
# ['NONE']
# ['IRL']
# ['Card & Board Game']
# ['FPS', 'Shooter', 'RPG']
# ['MMORPG']
# ['FPS', 'Shooter', 'Horror']
# ['Card & Board Game']
# ['Card & Board Game']
# ['IRL', 'Creative']
# ['Card & Board Game']
# ['MOBA']
# ['NONE']
# ['Shooter', 'FPS']
# ['RPG']
# ['RPG']
# ['MMORPG', 'RPG']
# ['Platformer']
# ...

# %%
games = [item for item in zip(game_list,game_list_cats)]

# %%
games[0][1]
# Out:
# ['Shooter', 'FPS']

# %%
# driver.close() #closes the page

# %%
#np.savetxt('game_and_category.csv', [item for item in zip(game_list,game_list_cats)], delimiter=',', fmt='%s')

# %%
final_games = pd.DataFrame(games,columns=['game', 'category'])

# %%
final_games.tail(20)
# Out:
#                                    game                category
# 978             Emily Wants to Play Too                  [NONE]
# 979                    Rise of Kingdoms      [RTS, Mobile Game]
# 980     Ni no Kuni II: Revenant Kingdom           [RPG, Action]
# 981  Eternal Darkness: Sanity's Requiem        [Action, Horror]
# 982                       The Universim            [Simulation]
# 983                     Dead or Alive 6              [Fighting]
# 984                   Monster Rancher 3  [Strategy, Simulation]
# 985  SEGA Mega Drive & Genesis Classics           [Compilation]
# 986         Captain Tsubasa: Dream Team           [Sports Game]
# 987                        Watch Dogs 2       [Shooter, Action]
# 988              Mass Effect: Andromeda           [RPG, Action]
# 989                   100% Orange Juice              [Strategy]
# 990                    This War of Mine              [Strategy]
# 991                   Tales of Berseria           [Action, RPG]
# ...

# %%
final_games.shape
# Out:
# (998, 2)

# %%
final_games.to_csv('game_genre_cat.csv',index=False)

# %%
final_games.to_pickle('final_games.p')

# %%
favorite_color = pickle.load( open( "final_games.p", "rb" ) )

# %%
unique_cats = set()
for item in favorite_color['category']:
    for letter in item:
        unique_cats.add(letter)

# %%
len(unique_cats)
# Out:
# 36

# %%
unique_cats
# Out:
# {'Action',
#  'Adventure Game',
#  'Autobattler',
#  'Card & Board Game',
#  'Compilation',
#  'Creative',
#  'Driving/Racing Game',
#  'Educational Game',
#  'FPS',
#  'Fighting',
#  'Flight Simulator',
#  'Gambling Game',
#  'Horror',
#  'IRL',
#  'Indie Game',
#  'MMORPG',
#  'MOBA',
#  'Metroidvania',
#  'Mobile Game',
#  'NONE',
#  'Open World',
#  'Pinball',
#  'Platformer',
#  'Point and Click',
#  'Puzzle',
#  'RPG',
#  'RTS',
#  'Rhythm & Music Game',
#  'Roguelike',
#  "Shoot 'Em Up",
#  'Shooter',
#  'Simulation',
#  'Sports Game',
#  'Stealth',
#  'Strategy',
#  'Survival'}
